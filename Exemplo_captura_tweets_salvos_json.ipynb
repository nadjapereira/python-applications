# %% [markdown]
# <a href="https://colab.research.google.com/github/nadjapereira/python-applications/blob/master/Exemplo_captura_tweets_salvos_json.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import json

# %%
dados = []
with open('tweets_5min.json') as arquivo:
    for linha in arquivo:
        dados.append(json.loads(linha))

# %%
df = pd.DataFrame(dados)
df
# Out:
#    contributors coordinates                      created_at  \
# 0          None        None  Mon Aug 01 21:16:54 +0000 2016
# 1          None        None  Mon Aug 01 21:17:01 +0000 2016
# 2          None        None  Mon Aug 01 21:17:03 +0000 2016
# 3          None        None  Mon Aug 01 21:17:13 +0000 2016
# 4          None        None  Mon Aug 01 21:17:19 +0000 2016
# 5          None        None  Mon Aug 01 21:17:25 +0000 2016
# 6          None        None  Mon Aug 01 21:17:34 +0000 2016
# 7          None        None  Mon Aug 01 21:17:39 +0000 2016
# 8          None        None  Mon Aug 01 21:17:42 +0000 2016
# 9          None        None  Mon Aug 01 21:17:42 +0000 2016
# 10         None        None  Mon Aug 01 21:17:45 +0000 2016
# 11         None        None  Mon Aug 01 21:17:48 +0000 2016
# 12         None        None  Mon Aug 01 21:17:51 +0000 2016
# 13         None        None  Mon Aug 01 21:17:53 +0000 2016
# 14         None        None  Mon Aug 01 21:17:53 +0000 2016
# ...
